# %%
import json
import spacy
import pprint

# %%
model = json.load( open( "../../bemr/py/.data/model.json","r"))

# %%
pprint.pprint(model)
# Out:
# {'model': {'-': {'negative': 2, 'positive': 6},
#            '- positive': {'mixed': 2},
#            '- positive mixed': {'infection': 2},
#            '--num': {'+': 1, 'cm': 2, 'days': 6, 'week': 1},
#            '--num days': {'ago': 5, 'despite': 1},
#            '--num days ago': {'associated': 2, 'no': 2},
#            '--num days despite': {'being': 1},
#            '--num week': {'despite': 1},
#            '--num week despite': {'being': 1},
#            '--parent': {'reported': 2, 'reports': 1},
#            '--parent reported': {'had': 2},
#            '--parent reported had': {'been': 2},
#            '--parent reports': {'of': 1},
#            '--parent reports of': {'poor': 1},
#            '--patient': {'exposure': 1,
#                          'had': 2,
#                          'is': 2,
#                          'reports': 6,
#                          'was': 2},
#            '--patient exposure': {'to': 1},
#            '--patient exposure to': {'a': 1},
# ...
